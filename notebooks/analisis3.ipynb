# %% [markdown]
# # Análisis de E-commerce — Olist
# ## Notebook 3: Análisis exploratorio (EDA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargamos la tabla maestra limpia
df = pd.read_csv('../data/olist_limpio.csv', parse_dates=['order_purchase_timestamp'])

print("Tabla cargada")
print("Shape:", df.shape)
